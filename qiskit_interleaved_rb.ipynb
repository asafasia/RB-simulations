# %% [markdown]
# # Two Qubit interleaved RB: Estimationg the fidelity of CNOT gate with Qiskit

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.optimize import curve_fit

from qiskit import QuantumCircuit, execute
from qiskit import qasm3, transpile, QuantumCircuit, Aer
from qiskit_aer.noise import depolarizing_error, NoiseModel
from qiskit_experiments.library import InterleavedRB

# %% [markdown]
# # Generate interleaved and sdandard rb sequenses for the experiment

# %%
# define the inteleaved gate (should be a circuit): CNOT
interleaved_element = QuantumCircuit(2)
interleaved_element.cx(0,1)


depths = np.array(range(1, 300, 20)) # sequence lengthes

num_samples = 5 # number of circuits per sequence length

qubits = [0,1] # number of qubits

qiskit_experiment = InterleavedRB(
    physical_qubits=qubits,
    num_samples=num_samples,
    lengths=depths,
    interleaved_element=interleaved_element,
    circuit_order='RRRIII',
    full_sampling = False
).circuits()


ground_state = '0' * len(qubits) # ground level (for two qubits = '00')

print(qiskit_experiment[1])
# Out:
#         ┌────────────────────┐ ░ ┌────────────────────┐ ░ »
#    q_0: ┤0                   ├─░─┤0                   ├─░─»
#         │  Clifford-2Q(4938) │ ░ │  Clifford-2Q(5412) │ ░ »
#    q_1: ┤1                   ├─░─┤1                   ├─░─»
#         └────────────────────┘ ░ └────────────────────┘ ░ »
# meas: 2/══════════════════════════════════════════════════»
#                                                           »
# «        ┌────────────────────┐ ░ ┌────────────────────┐ ░ »
# «   q_0: ┤0                   ├─░─┤0                   ├─░─»
# «        │  Clifford-2Q(2153) │ ░ │  Clifford-2Q(1435) │ ░ »
# «   q_1: ┤1                   ├─░─┤1                   ├─░─»
# «        └────────────────────┘ ░ └────────────────────┘ ░ »
# «meas: 2/══════════════════════════════════════════════════»
# «                                                          »
# «        ┌────────────────────┐ ░ ┌────────────────────┐ ░ »
# «   q_0: ┤0                   ├─░─┤0                   ├─░─»
# «        │  Clifford-2Q(1030) │ ░ │  Clifford-2Q(8269) │ ░ »
# «   q_1: ┤1                   ├─░─┤1                   ├─░─»
# «        └────────────────────┘ ░ └────────────────────┘ ░ »
# «meas: 2/══════════════════════════════════════════════════»
# «                                                          »
# «        ┌────────────────────┐ ░ ┌────────────────────┐ ░ »
# «   q_0: ┤0                   ├─░─┤0                   ├─░─»
# «        │  Clifford-2Q(6391) │ ░ │  Clifford-2Q(7313) │ ░ »
# «   q_1: ┤1                   ├─░─┤1                   ├─░─»
# «        └────────────────────┘ ░ └────────────────────┘ ░ »
# «meas: 2/══════════════════════════════════════════════════»
# «                                                          »
# «        ┌────────────────────┐ ░ ┌────────────────────┐ ░ »
# «   q_0: ┤0                   ├─░─┤0                   ├─░─»
# «        │  Clifford-2Q(1992) │ ░ │  Clifford-2Q(5693) │ ░ »
# «   q_1: ┤1                   ├─░─┤1                   ├─░─»
# «        └────────────────────┘ ░ └────────────────────┘ ░ »
# «meas: 2/══════════════════════════════════════════════════»
# «                                                          »
# «        ┌───────────────────┐ ░ ┌────────────────────┐ ░ »
# «   q_0: ┤0                  ├─░─┤0                   ├─░─»
# «        │  Clifford-2Q(374) │ ░ │  Clifford-2Q(9795) │ ░ »
# «   q_1: ┤1                  ├─░─┤1                   ├─░─»
# «        └───────────────────┘ ░ └────────────────────┘ ░ »
# «meas: 2/═════════════════════════════════════════════════»
# «                                                         »
# «        ┌────────────────────┐ ░ ┌────────────────────┐ ░ »
# «   q_0: ┤0                   ├─░─┤0                   ├─░─»
# «        │  Clifford-2Q(3100) │ ░ │  Clifford-2Q(8395) │ ░ »
# «   q_1: ┤1                   ├─░─┤1                   ├─░─»
# «        └────────────────────┘ ░ └────────────────────┘ ░ »
# «meas: 2/══════════════════════════════════════════════════»
# «                                                          »
# «        ┌────────────────────┐ ░ ┌────────────────────┐ ░ »
# «   q_0: ┤0                   ├─░─┤0                   ├─░─»
# «        │  Clifford-2Q(4795) │ ░ │  Clifford-2Q(9635) │ ░ »
# «   q_1: ┤1                   ├─░─┤1                   ├─░─»
# «        └────────────────────┘ ░ └────────────────────┘ ░ »
# «meas: 2/══════════════════════════════════════════════════»
# «                                                          »
# «        ┌────────────────────┐ ░ ┌────────────────────┐ ░ »
# «   q_0: ┤0                   ├─░─┤0                   ├─░─»
# «        │  Clifford-2Q(7141) │ ░ │  Clifford-2Q(6884) │ ░ »
# «   q_1: ┤1                   ├─░─┤1                   ├─░─»
# «        └────────────────────┘ ░ └────────────────────┘ ░ »
# «meas: 2/══════════════════════════════════════════════════»
# «                                                          »
# «        ┌────────────────────┐ ░ ┌────────────────────┐ ░ »
# «   q_0: ┤0                   ├─░─┤0                   ├─░─»
# «        │  Clifford-2Q(6157) │ ░ │  Clifford-2Q(5244) │ ░ »
# «   q_1: ┤1                   ├─░─┤1                   ├─░─»
# «        └────────────────────┘ ░ └────────────────────┘ ░ »
# «meas: 2/══════════════════════════════════════════════════»
# «                                                          »
# «        ┌───────────────────┐ ░ ┌────────────────────┐ ░ ┌─┐
# «   q_0: ┤0                  ├─░─┤0                   ├─░─┤M├───
# «        │  Clifford-2Q(359) │ ░ │  Clifford-2Q(2166) │ ░ └╥┘┌─┐
# «   q_1: ┤1                  ├─░─┤1                   ├─░──╫─┤M├
# «        └───────────────────┘ ░ └────────────────────┘ ░  ║ └╥┘
# «meas: 2/══════════════════════════════════════════════════╩══╩═
# «                                                          0  1

# %% [markdown]
# # Transpile the circuits to same native gates choise

# %%
basis_gates = ["id", "sx", "x", "rz", "cx"]

transpiled_circuit = transpile(qiskit_experiment, basis_gates = basis_gates)

print(transpiled_circuit[-1])
# Out:
# global phase: π
#         ┌─────────┐┌────┐ ┌────────┐     ┌───┐┌────┐┌──────────┐ ░       ░ »
#    q_0: ┤ Rz(π/2) ├┤ √X ├─┤ Rz(-π) ├──■──┤ X ├┤ √X ├┤ Rz(-π/2) ├─░───■───░─»
#         ├─────────┤├────┤┌┴────────┤┌─┴─┐└─┬─┘├────┤├──────────┤ ░ ┌─┴─┐ ░ »
#    q_1: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ X ├──■──┤ √X ├┤ Rz(-π/2) ├─░─┤ X ├─░─»
#         └─────────┘└────┘└─────────┘└───┘     └────┘└──────────┘ ░ └───┘ ░ »
# meas: 2/═══════════════════════════════════════════════════════════════════»
#                                                                            »
# «        ┌─────────┐┌────┐┌────────┐     ┌───┐┌──────────┐┌────┐ ░       ░ »
# «   q_0: ┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├──■──┤ X ├┤ Rz(-π/2) ├┤ √X ├─░───■───░─»
# «        └┬────────┤├────┤├────────┤┌─┴─┐└─┬─┘├──────────┤├────┤ ░ ┌─┴─┐ ░ »
# «   q_1: ─┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├┤ X ├──■──┤ Rz(-π/2) ├┤ √X ├─░─┤ X ├─░─»
# «         └────────┘└────┘└────────┘└───┘     └──────────┘└────┘ ░ └───┘ ░ »
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «                        ┌───┐┌─────────┐ ┌────┐┌────────┐ ░       ░ ┌────────┐»
# «   q_0: ─────────────■──┤ X ├┤ Rz(π/2) ├─┤ √X ├┤ Rz(-π) ├─░───■───░─┤ Rz(-π) ├»
# «        ┌─────────┐┌─┴─┐└─┬─┘├─────────┴┐├────┤├────────┤ ░ ┌─┴─┐ ░ └─┬────┬─┘»
# «   q_1: ┤ Rz(π/2) ├┤ X ├──■──┤ Rz(-π/2) ├┤ √X ├┤ Rz(-π) ├─░─┤ X ├─░───┤ √X ├──»
# «        └─────────┘└───┘     └──────────┘└────┘└────────┘ ░ └───┘ ░   └────┘  »
# «meas: 2/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «           ┌────┐  ┌────────┐     ┌───┐┌───────┐   ┌───┐     ░       ░ »
# «   q_0: ───┤ √X ├──┤ Rz(-π) ├──■──┤ X ├┤ Rz(π) ├───┤ X ├─────░───■───░─»
# «        ┌──┴────┴─┐└────────┘┌─┴─┐└─┬─┘└─┬────┬┘┌──┴───┴───┐ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(π/2) ├──────────┤ X ├──■────┤ √X ├─┤ Rz(-π/2) ├─░─┤ X ├─░─»
# «        └─────────┘          └───┘       └────┘ └──────────┘ ░ └───┘ ░ »
# «meas: 2/═══════════════════════════════════════════════════════════════»
# «                                                                       »
# «                        ┌───┐┌──────────┐┌────┐┌────────┐ ░       ░ »
# «   q_0: ─────────────■──┤ X ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(-π) ├─░───■───░─»
# «        ┌─────────┐┌─┴─┐└─┬─┘└──┬───┬───┘└────┘└────────┘ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(π/2) ├┤ X ├──■─────┤ X ├─────────────────────░─┤ X ├─░─»
# «        └─────────┘└───┘        └───┘                     ░ └───┘ ░ »
# «meas: 2/════════════════════════════════════════════════════════════»
# «                                                                    »
# «        ┌─────────┐┌────┐┌────────┐     ┌───┐                  ░       ░ »
# «   q_0: ┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├──■──┤ X ├──────────────────░───■───░─»
# «        └┬────────┤├────┤├────────┤┌─┴─┐└─┬─┘┌────┐┌─────────┐ ░ ┌─┴─┐ ░ »
# «   q_1: ─┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├┤ X ├──■──┤ √X ├┤ Rz(π/2) ├─░─┤ X ├─░─»
# «         └────────┘└────┘└────────┘└───┘     └────┘└─────────┘ ░ └───┘ ░ »
# «meas: 2/═════════════════════════════════════════════════════════════════»
# «                                                                         »
# «        ┌─────────┐┌────┐┌─────────┐     ┌─────────┐┌────┐ ░       ░ »
# «   q_0: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├──■──┤ Rz(π/2) ├┤ √X ├─░───■───░─»
# «        ├─────────┤├────┤└┬────────┤┌─┴─┐└─────────┘└────┘ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(π/2) ├┤ √X ├─┤ Rz(-π) ├┤ X ├──────────────────░─┤ X ├─░─»
# «        └─────────┘└────┘ └────────┘└───┘                  ░ └───┘ ░ »
# «meas: 2/═════════════════════════════════════════════════════════════»
# «                                                                     »
# «         ┌────────┐┌────┐ ┌────────┐     ┌───┐┌───────┐┌───┐ ░       ░ »
# «   q_0: ─┤ Rz(-π) ├┤ √X ├─┤ Rz(-π) ├──■──┤ X ├┤ Rz(π) ├┤ X ├─░───■───░─»
# «        ┌┴────────┤├────┤┌┴────────┤┌─┴─┐└─┬─┘└───────┘└───┘ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ X ├──■─────────────────░─┤ X ├─░─»
# «        └─────────┘└────┘└─────────┘└───┘                    ░ └───┘ ░ »
# «meas: 2/═══════════════════════════════════════════════════════════════»
# «                                                                       »
# «         ┌────────┐┌────┐┌────────┐     ┌───┐┌──────────┐┌────┐ ░       ░ »
# «   q_0: ─┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├──■──┤ X ├┤ Rz(-π/2) ├┤ √X ├─░───■───░─»
# «        ┌┴────────┤└────┘└────────┘┌─┴─┐└─┬─┘└┬───────┬─┘└────┘ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(π/2) ├────────────────┤ X ├──■───┤ Rz(π) ├─────────░─┤ X ├─░─»
# «        └─────────┘                └───┘      └───────┘         ░ └───┘ ░ »
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌─────────┐                     ┌───┐┌──────────┐┌────┐            ░ »
# «   q_0: ┤ Rz(π/2) ├──────────────────■──┤ X ├┤ Rz(-π/2) ├┤ √X ├────────────░─»
# «        ├─────────┤┌────┐┌────────┐┌─┴─┐└─┬─┘└┬────────┬┘├────┤┌─────────┐ ░ »
# «   q_1: ┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├┤ X ├──■───┤ Rz(-π) ├─┤ √X ├┤ Rz(π/2) ├─░─»
# «        └─────────┘└────┘└────────┘└───┘      └────────┘ └────┘└─────────┘ ░ »
# «meas: 2/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «              ░  ┌────────┐┌────┐┌────────┐     ┌─────────┐┌────┐ ░       ░ »
# «   q_0: ──■───░──┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├──■──┤ Rz(π/2) ├┤ √X ├─░───■───░─»
# «        ┌─┴─┐ ░ ┌┴────────┤└────┘└────────┘┌─┴─┐└──┬───┬──┘└────┘ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ X ├─░─┤ Rz(π/2) ├────────────────┤ X ├───┤ X ├──────────░─┤ X ├─░─»
# «        └───┘ ░ └─────────┘                └───┘   └───┘          ░ └───┘ ░ »
# «meas: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «        ┌─────────┐                     ┌───┐┌──────────┐┌────┐ ░       ░ »
# «   q_0: ┤ Rz(π/2) ├──────────────────■──┤ X ├┤ Rz(-π/2) ├┤ √X ├─░───■───░─»
# «        ├─────────┤┌────┐┌────────┐┌─┴─┐└─┬─┘├──────────┤├────┤ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├┤ X ├──■──┤ Rz(-π/2) ├┤ √X ├─░─┤ X ├─░─»
# «        └─────────┘└────┘└────────┘└───┘     └──────────┘└────┘ ░ └───┘ ░ »
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «         ┌────────┐┌────┐┌────────┐     ┌───┐     ┌───┐ ░       ░ ┌─────────┐»
# «   q_0: ─┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├──■──┤ X ├──■──┤ X ├─░───■───░─┤ Rz(π/2) ├»
# «        ┌┴────────┤├────┤├────────┤┌─┴─┐└─┬─┘┌─┴─┐└───┘ ░ ┌─┴─┐ ░ ├─────────┤»
# «   q_1: ┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├┤ X ├──■──┤ X ├──────░─┤ X ├─░─┤ Rz(π/2) ├»
# «        └─────────┘└────┘└────────┘└───┘     └───┘      ░ └───┘ ░ └─────────┘»
# «meas: 2/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «        ┌────┐┌────────┐     ┌───┐   ┌───┐          ░       ░  ┌────────┐»
# «   q_0: ┤ √X ├┤ Rz(-π) ├──■──┤ X ├───┤ X ├──────────░───■───░──┤ Rz(-π) ├»
# «        ├────┤├────────┤┌─┴─┐└─┬─┘┌──┴───┴──┐┌────┐ ░ ┌─┴─┐ ░ ┌┴────────┤»
# «   q_1: ┤ √X ├┤ Rz(-π) ├┤ X ├──■──┤ Rz(π/2) ├┤ √X ├─░─┤ X ├─░─┤ Rz(π/2) ├»
# «        └────┘└────────┘└───┘     └─────────┘└────┘ ░ └───┘ ░ └─────────┘»
# «meas: 2/═════════════════════════════════════════════════════════════════»
# «                                                                         »
# «        ┌────┐┌────────┐     ┌───┐┌─────────┐ ┌────┐ ░       ░ ┌─────────┐»
# «   q_0: ┤ √X ├┤ Rz(-π) ├──■──┤ X ├┤ Rz(π/2) ├─┤ √X ├─░───■───░─┤ Rz(π/2) ├»
# «        ├────┤├────────┤┌─┴─┐└─┬─┘├─────────┴┐├────┤ ░ ┌─┴─┐ ░ └─────────┘»
# «   q_1: ┤ √X ├┤ Rz(-π) ├┤ X ├──■──┤ Rz(-π/2) ├┤ √X ├─░─┤ X ├─░────────────»
# «        └────┘└────────┘└───┘     └──────────┘└────┘ ░ └───┘ ░            »
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «             ┌───────┐ ┌───┐             ░       ░ ┌─────────┐┌────┐»
# «   q_0: ──■──┤ Rz(π) ├─┤ X ├─────────────░───■───░─┤ Rz(π/2) ├┤ √X ├»
# «        ┌─┴─┐├───────┴┐├───┴┐┌─────────┐ ░ ┌─┴─┐ ░ ├─────────┤├────┤»
# «   q_1: ┤ X ├┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├─░─┤ X ├─░─┤ Rz(π/2) ├┤ √X ├»
# «        └───┘└────────┘└────┘└─────────┘ ░ └───┘ ░ └─────────┘└────┘»
# «meas: 2/════════════════════════════════════════════════════════════»
# «                                                                    »
# «        ┌─────────┐     ┌───┐┌──────────┐┌────┐┌────────┐ ░       ░ »
# «   q_0: ┤ Rz(π/2) ├──■──┤ X ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(-π) ├─░───■───░─»
# «        └┬────────┤┌─┴─┐└─┬─┘└──┬───┬───┘└────┘└────────┘ ░ ┌─┴─┐ ░ »
# «   q_1: ─┤ Rz(-π) ├┤ X ├──■─────┤ X ├─────────────────────░─┤ X ├─░─»
# «         └────────┘└───┘        └───┘                     ░ └───┘ ░ »
# «meas: 2/════════════════════════════════════════════════════════════»
# «                                                                    »
# «        ┌─────────┐┌────┐┌─────────┐     ┌───┐     ┌───────┐      ░       ░ »
# «   q_0: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├──■──┤ X ├──■──┤ Rz(π) ├──────░───■───░─»
# «        └─────────┘└────┘└─────────┘┌─┴─┐└─┬─┘┌─┴─┐├───────┤┌───┐ ░ ┌─┴─┐ ░ »
# «   q_1: ────────────────────────────┤ X ├──■──┤ X ├┤ Rz(π) ├┤ X ├─░─┤ X ├─░─»
# «                                    └───┘     └───┘└───────┘└───┘ ░ └───┘ ░ »
# «meas: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «        ┌─────────┐┌────┐┌────────┐     ┌───┐┌──────────┐   ┌────┐    ░      »
# «   q_0: ┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├──■──┤ X ├┤ Rz(-π/2) ├───┤ √X ├────░───■──»
# «        ├─────────┤├────┤├────────┤┌─┴─┐└─┬─┘└──┬────┬──┘┌──┴────┴──┐ ░ ┌─┴─┐»
# «   q_1: ┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├┤ X ├──■─────┤ √X ├───┤ Rz(-π/2) ├─░─┤ X ├»
# «        └─────────┘└────┘└────────┘└───┘        └────┘   └──────────┘ ░ └───┘»
# «meas: 2/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «         ░                  ░       ░ ┌─────────┐┌────┐┌─────────┐     »
# «   q_0: ─░──────────────────░───■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├──■──»
# «         ░ ┌────────┐┌────┐ ░ ┌─┴─┐ ░ └┬────────┤├────┤└┬────────┤┌─┴─┐»
# «   q_1: ─░─┤ Rz(-π) ├┤ √X ├─░─┤ X ├─░──┤ Rz(-π) ├┤ √X ├─┤ Rz(-π) ├┤ X ├»
# «         ░ └────────┘└────┘ ░ └───┘ ░  └────────┘└────┘ └────────┘└───┘»
# «meas: 2/═══════════════════════════════════════════════════════════════»
# «                                                                       »
# «        ┌────────┐   ┌────┐  ┌──────────┐ ░       ░   ┌────┐  ┌─────────┐»
# «   q_0: ┤ Rz(-π) ├───┤ √X ├──┤ Rz(-π/2) ├─░───■───░───┤ √X ├──┤ Rz(π/2) ├»
# «        └─┬────┬─┘┌──┴────┴─┐└──────────┘ ░ ┌─┴─┐ ░ ┌─┴────┴─┐└──┬────┬─┘»
# «   q_1: ──┤ √X ├──┤ Rz(π/2) ├─────────────░─┤ X ├─░─┤ Rz(-π) ├───┤ √X ├──»
# «          └────┘  └─────────┘             ░ └───┘ ░ └────────┘   └────┘  »
# «meas: 2/═════════════════════════════════════════════════════════════════»
# «                                                                         »
# «                       ┌─────────┐┌────┐┌────────┐ ░       ░  ┌────────┐┌────┐»
# «   q_0: ────────────■──┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├─░───■───░──┤ Rz(-π) ├┤ √X ├»
# «        ┌────────┐┌─┴─┐└┬───────┬┘└────┘└────────┘ ░ ┌─┴─┐ ░ ┌┴────────┤├────┤»
# «   q_1: ┤ Rz(-π) ├┤ X ├─┤ Rz(π) ├──────────────────░─┤ X ├─░─┤ Rz(π/2) ├┤ √X ├»
# «        └────────┘└───┘ └───────┘                  ░ └───┘ ░ └─────────┘└────┘»
# «meas: 2/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌────────┐      ┌────────┐ ┌────┐┌──────────┐ ░       ░ ┌─────────┐»
# «   q_0: ┤ Rz(-π) ├──■───┤ Rz(-π) ├─┤ √X ├┤ Rz(-π/2) ├─░───■───░─┤ Rz(π/2) ├»
# «        ├────────┤┌─┴─┐┌┴────────┴┐├────┤└┬────────┬┘ ░ ┌─┴─┐ ░ ├─────────┤»
# «   q_1: ┤ Rz(-π) ├┤ X ├┤ Rz(-π/2) ├┤ √X ├─┤ Rz(-π) ├──░─┤ X ├─░─┤ Rz(π/2) ├»
# «        └────────┘└───┘└──────────┘└────┘ └────────┘  ░ └───┘ ░ └─────────┘»
# «meas: 2/═══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «        ┌────┐┌────────┐     ┌─────────┐┌────┐ ░       ░  ┌────────┐┌────┐»
# «   q_0: ┤ √X ├┤ Rz(-π) ├──■──┤ Rz(π/2) ├┤ √X ├─░───■───░──┤ Rz(-π) ├┤ √X ├»
# «        └────┘└────────┘┌─┴─┐└┬───────┬┘└────┘ ░ ┌─┴─┐ ░ ┌┴────────┤├────┤»
# «   q_1: ────────────────┤ X ├─┤ Rz(π) ├────────░─┤ X ├─░─┤ Rz(π/2) ├┤ √X ├»
# «                        └───┘ └───────┘        ░ └───┘ ░ └─────────┘└────┘»
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌────────┐     ┌───┐┌──────────┐┌────┐┌────────┐ ░       ░            »
# «   q_0: ┤ Rz(-π) ├──■──┤ X ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(-π) ├─░───■───░────────────»
# «        ├────────┤┌─┴─┐└─┬─┘├─────────┬┘├────┤├────────┤ ░ ┌─┴─┐ ░ ┌─────────┐»
# «   q_1: ┤ Rz(-π) ├┤ X ├──■──┤ Rz(π/2) ├─┤ √X ├┤ Rz(-π) ├─░─┤ X ├─░─┤ Rz(π/2) ├»
# «        └────────┘└───┘     └─────────┘ └────┘└────────┘ ░ └───┘ ░ └─────────┘»
# «meas: 2/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                             ┌───────┐ ┌───┐              ░       ░ »
# «   q_0: ──────────────────■──┤ Rz(π) ├─┤ X ├──────────────░───■───░─»
# «        ┌────┐┌────────┐┌─┴─┐├───────┴┐├───┴┐┌──────────┐ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ √X ├┤ Rz(-π) ├┤ X ├┤ Rz(-π) ├┤ √X ├┤ Rz(-π/2) ├─░─┤ X ├─░─»
# «        └────┘└────────┘└───┘└────────┘└────┘└──────────┘ ░ └───┘ ░ »
# «meas: 2/════════════════════════════════════════════════════════════»
# «                                                                    »
# «         ┌────────┐┌────┐┌────────┐     ┌───┐┌───────┐ ░       ░            »
# «   q_0: ─┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├──■──┤ X ├┤ Rz(π) ├─░───■───░────────────»
# «        ┌┴────────┤├────┤├────────┤┌─┴─┐└─┬─┘├───────┤ ░ ┌─┴─┐ ░ ┌─────────┐»
# «   q_1: ┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├┤ X ├──■──┤ Rz(π) ├─░─┤ X ├─░─┤ Rz(π/2) ├»
# «        └─────────┘└────┘└────────┘└───┘     └───────┘ ░ └───┘ ░ └─────────┘»
# «meas: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «             ┌───┐  ┌────┐  ┌─────────┐            ░       ░ ┌────┐»
# «   q_0: ──■──┤ X ├──┤ √X ├──┤ Rz(π/2) ├────────────░───■───░─┤ √X ├»
# «        ┌─┴─┐└─┬─┘┌─┴────┴─┐└──┬────┬─┘┌─────────┐ ░ ┌─┴─┐ ░ ├────┤»
# «   q_1: ┤ X ├──■──┤ Rz(-π) ├───┤ √X ├──┤ Rz(π/2) ├─░─┤ X ├─░─┤ √X ├»
# «        └───┘     └────────┘   └────┘  └─────────┘ ░ └───┘ ░ └────┘»
# «meas: 2/═══════════════════════════════════════════════════════════»
# «                                                                   »
# «        ┌─────────┐  ░       ░ ┌─────────┐   ┌────┐  ┌────────┐       ┌────┐  »
# «   q_0: ┤ Rz(π/2) ├──░───■───░─┤ Rz(π/2) ├───┤ √X ├──┤ Rz(-π) ├──■────┤ √X ├──»
# «        ├─────────┴┐ ░ ┌─┴─┐ ░ └──┬────┬─┘┌──┴────┴─┐└────────┘┌─┴─┐┌─┴────┴─┐»
# «   q_1: ┤ Rz(-π/2) ├─░─┤ X ├─░────┤ √X ├──┤ Rz(π/2) ├──────────┤ X ├┤ Rz(-π) ├»
# «        └──────────┘ ░ └───┘ ░    └────┘  └─────────┘          └───┘└────────┘»
# «meas: 2/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌──────────┐            ░       ░                       ┌───┐»
# «   q_0: ┤ Rz(-π/2) ├────────────░───■───░────────────────────■──┤ X ├»
# «        └──┬────┬──┘┌─────────┐ ░ ┌─┴─┐ ░ ┌────┐┌─────────┐┌─┴─┐└─┬─┘»
# «   q_1: ───┤ √X ├───┤ Rz(π/2) ├─░─┤ X ├─░─┤ √X ├┤ Rz(π/2) ├┤ X ├──■──»
# «           └────┘   └─────────┘ ░ └───┘ ░ └────┘└─────────┘└───┘     »
# «meas: 2/═════════════════════════════════════════════════════════════»
# «                                                                     »
# «        ┌─────────┐ ┌────┐┌────────┐ ░       ░ ┌─────────┐     ┌───┐»
# «   q_0: ┤ Rz(π/2) ├─┤ √X ├┤ Rz(-π) ├─░───■───░─┤ Rz(π/2) ├──■──┤ X ├»
# «        ├─────────┴┐├────┤└────────┘ ░ ┌─┴─┐ ░ ├─────────┤┌─┴─┐└─┬─┘»
# «   q_1: ┤ Rz(-π/2) ├┤ √X ├───────────░─┤ X ├─░─┤ Rz(π/2) ├┤ X ├──■──»
# «        └──────────┘└────┘           ░ └───┘ ░ └─────────┘└───┘     »
# «meas: 2/════════════════════════════════════════════════════════════»
# «                                                                    »
# «        ┌──────────┐┌────┐┌────────┐ ░       ░                             »
# «   q_0: ┤ Rz(-π/2) ├┤ √X ├┤ Rz(-π) ├─░───■───░─────────────────────────────»
# «        └┬───────┬─┘└────┘└────────┘ ░ ┌─┴─┐ ░ ┌─────────┐┌────┐┌─────────┐»
# «   q_1: ─┤ Rz(π) ├───────────────────░─┤ X ├─░─┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├»
# «         └───────┘                   ░ └───┘ ░ └─────────┘└────┘└─────────┘»
# «meas: 2/═══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «                                ░       ░ ┌─────────┐┌────┐┌────────┐     »
# «   q_0: ──■─────────────────────░───■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├──■──»
# «        ┌─┴─┐┌────┐┌──────────┐ ░ ┌─┴─┐ ░ └┬────────┤├────┤├────────┤┌─┴─┐»
# «   q_1: ┤ X ├┤ √X ├┤ Rz(-π/2) ├─░─┤ X ├─░──┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├┤ X ├»
# «        └───┘└────┘└──────────┘ ░ └───┘ ░  └────────┘└────┘└────────┘└───┘»
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «         ┌───────┐         ░       ░      ┌───┐┌───────┐   ┌───┐     ░      »
# «   q_0: ─┤ Rz(π) ├─────────░───■───░───■──┤ X ├┤ Rz(π) ├───┤ X ├─────░───■──»
# «        ┌┴───────┴─┐┌────┐ ░ ┌─┴─┐ ░ ┌─┴─┐└─┬─┘└─┬────┬┘┌──┴───┴───┐ ░ ┌─┴─┐»
# «   q_1: ┤ Rz(-π/2) ├┤ √X ├─░─┤ X ├─░─┤ X ├──■────┤ √X ├─┤ Rz(-π/2) ├─░─┤ X ├»
# «        └──────────┘└────┘ ░ └───┘ ░ └───┘       └────┘ └──────────┘ ░ └───┘»
# «meas: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «         ░   ┌────┐  ┌─────────┐                ┌───────┐ ┌───┐            ░ »
# «   q_0: ─░───┤ √X ├──┤ Rz(π/2) ├────────────■───┤ Rz(π) ├─┤ X ├────────────░─»
# «         ░ ┌─┴────┴─┐└──┬────┬─┘┌────────┐┌─┴─┐┌┴───────┴┐├───┴┐┌────────┐ ░ »
# «   q_1: ─░─┤ Rz(-π) ├───┤ √X ├──┤ Rz(-π) ├┤ X ├┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├─░─»
# «         ░ └────────┘   └────┘  └────────┘└───┘└─────────┘└────┘└────────┘ ░ »
# «meas: 2/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «              ░ ┌─────────┐┌────┐┌────────┐     ┌───────┐ ░       ░ ┌────────┐»
# «   q_0: ──■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├──■──┤ Rz(π) ├─░───■───░─┤ Rz(-π) ├»
# «        ┌─┴─┐ ░ ├─────────┤└────┘└────────┘┌─┴─┐└───────┘ ░ ┌─┴─┐ ░ ├────────┤»
# «   q_1: ┤ X ├─░─┤ Rz(π/2) ├────────────────┤ X ├──────────░─┤ X ├─░─┤ Rz(-π) ├»
# «        └───┘ ░ └─────────┘                └───┘          ░ └───┘ ░ └────────┘»
# «meas: 2/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌────┐┌────────┐     ┌────────┐┌────┐┌─────────┐ ░       ░  ┌────────┐»
# «   q_0: ┤ √X ├┤ Rz(-π) ├──■──┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├─░───■───░──┤ Rz(-π) ├»
# «        ├────┤├────────┤┌─┴─┐└─┬───┬──┘└────┘└─────────┘ ░ ┌─┴─┐ ░ ┌┴────────┤»
# «   q_1: ┤ √X ├┤ Rz(-π) ├┤ X ├──┤ X ├─────────────────────░─┤ X ├─░─┤ Rz(π/2) ├»
# «        └────┘└────────┘└───┘  └───┘                     ░ └───┘ ░ └─────────┘»
# «meas: 2/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌────┐ ┌────────┐     ┌───────┐                    ░       ░ »
# «   q_0: ┤ √X ├─┤ Rz(-π) ├──■──┤ Rz(π) ├────────────────────░───■───░─»
# «        ├────┤┌┴────────┤┌─┴─┐├───────┴┐┌────┐┌──────────┐ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ √X ├┤ Rz(π/2) ├┤ X ├┤ Rz(-π) ├┤ √X ├┤ Rz(-π/2) ├─░─┤ X ├─░─»
# «        └────┘└─────────┘└───┘└────────┘└────┘└──────────┘ ░ └───┘ ░ »
# «meas: 2/═════════════════════════════════════════════════════════════»
# «                                                                     »
# «        ┌─────────┐┌────┐ ┌────────┐     ┌────┐┌─────────┐ ░       ░ »
# «   q_0: ┤ Rz(π/2) ├┤ √X ├─┤ Rz(-π) ├──■──┤ √X ├┤ Rz(π/2) ├─░───■───░─»
# «        ├─────────┤├────┤┌┴────────┤┌─┴─┐├────┤├─────────┤ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ X ├┤ √X ├┤ Rz(π/2) ├─░─┤ X ├─░─»
# «        └─────────┘└────┘└─────────┘└───┘└────┘└─────────┘ ░ └───┘ ░ »
# «meas: 2/═════════════════════════════════════════════════════════════»
# «                                                                     »
# «        ┌─────────┐                         ┌────┐  ┌─────────┐ ░       ░ »
# «   q_0: ┤ Rz(π/2) ├───────────────────■─────┤ √X ├──┤ Rz(π/2) ├─░───■───░─»
# «        ├─────────┤┌────┐┌─────────┐┌─┴─┐┌──┴────┴─┐└──┬────┬─┘ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ X ├┤ Rz(π/2) ├───┤ √X ├───░─┤ X ├─░─»
# «        └─────────┘└────┘└─────────┘└───┘└─────────┘   └────┘   ░ └───┘ ░ »
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌─────────┐┌────┐┌─────────┐        ┌────┐   ┌─────────┐ ░       ░ »
# «   q_0: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├──■─────┤ √X ├───┤ Rz(π/2) ├─░───■───░─»
# «        └─────────┘└────┘└─────────┘┌─┴─┐┌──┴────┴──┐└──┬────┬─┘ ░ ┌─┴─┐ ░ »
# «   q_1: ────────────────────────────┤ X ├┤ Rz(-π/2) ├───┤ √X ├───░─┤ X ├─░─»
# «                                    └───┘└──────────┘   └────┘   ░ └───┘ ░ »
# «meas: 2/═══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «        ┌─────────┐                     ┌────┐┌─────────┐  ░       ░       »
# «   q_0: ┤ Rz(π/2) ├──────────────────■──┤ √X ├┤ Rz(π/2) ├──░───■───░───────»
# «        ├─────────┤┌────┐┌────────┐┌─┴─┐├────┤├─────────┴┐ ░ ┌─┴─┐ ░ ┌────┐»
# «   q_1: ┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├┤ X ├┤ √X ├┤ Rz(-π/2) ├─░─┤ X ├─░─┤ √X ├»
# «        └─────────┘└────┘└────────┘└───┘└────┘└──────────┘ ░ └───┘ ░ └────┘»
# «meas: 2/═══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «                        ┌───┐  ┌────┐  ┌─────────┐             ░       ░ »
# «   q_0: ─────────────■──┤ X ├──┤ √X ├──┤ Rz(π/2) ├─────────────░───■───░─»
# «        ┌─────────┐┌─┴─┐└─┬─┘┌─┴────┴─┐└──┬────┬─┘┌──────────┐ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(π/2) ├┤ X ├──■──┤ Rz(-π) ├───┤ √X ├──┤ Rz(-π/2) ├─░─┤ X ├─░─»
# «        └─────────┘└───┘     └────────┘   └────┘  └──────────┘ ░ └───┘ ░ »
# «meas: 2/═════════════════════════════════════════════════════════════════»
# «                                                                         »
# «           ┌────┐  ┌─────────┐                ┌───┐┌───────┐┌───┐ ░       ░ »
# «   q_0: ───┤ √X ├──┤ Rz(π/2) ├─────────────■──┤ X ├┤ Rz(π) ├┤ X ├─░───■───░─»
# «        ┌──┴────┴─┐└──┬────┬─┘┌─────────┐┌─┴─┐└─┬─┘├───────┤├───┤ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(π/2) ├───┤ √X ├──┤ Rz(π/2) ├┤ X ├──■──┤ Rz(π) ├┤ X ├─░─┤ X ├─░─»
# «        └─────────┘   └────┘  └─────────┘└───┘     └───────┘└───┘ ░ └───┘ ░ »
# «meas: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «        ┌────────┐┌────┐┌────────┐        ┌────┐   ┌─────────┐           ░ »
# «   q_0: ┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├──■─────┤ √X ├───┤ Rz(π/2) ├───────────░─»
# «        └────────┘└────┘└────────┘┌─┴─┐┌──┴────┴──┐└──┬────┬─┘┌────────┐ ░ »
# «   q_1: ──────────────────────────┤ X ├┤ Rz(-π/2) ├───┤ √X ├──┤ Rz(-π) ├─░─»
# «                                  └───┘└──────────┘   └────┘  └────────┘ ░ »
# «meas: 2/═══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «              ░ ┌─────────┐┌────┐┌─────────┐     ┌───────┐ ░       ░ »
# «   q_0: ──■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├──■──┤ Rz(π) ├─░───■───░─»
# «        ┌─┴─┐ ░ ├─────────┤├────┤└┬────────┤┌─┴─┐├───────┤ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ X ├─░─┤ Rz(π/2) ├┤ √X ├─┤ Rz(-π) ├┤ X ├┤ Rz(π) ├─░─┤ X ├─░─»
# «        └───┘ ░ └─────────┘└────┘ └────────┘└───┘└───────┘ ░ └───┘ ░ »
# «meas: 2/═════════════════════════════════════════════════════════════»
# «                                                                     »
# «        ┌─────────┐┌────┐ ┌────────┐     ┌───┐     ┌───────┐┌───┐ ░       ░ »
# «   q_0: ┤ Rz(π/2) ├┤ √X ├─┤ Rz(-π) ├──■──┤ X ├──■──┤ Rz(π) ├┤ X ├─░───■───░─»
# «        ├─────────┤├────┤┌┴────────┤┌─┴─┐└─┬─┘┌─┴─┐├───────┤├───┤ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ X ├──■──┤ X ├┤ Rz(π) ├┤ X ├─░─┤ X ├─░─»
# «        └─────────┘└────┘└─────────┘└───┘     └───┘└───────┘└───┘ ░ └───┘ ░ »
# «meas: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «           ┌────┐  ┌─────────┐     ┌───────┐ ┌───┐              ░       ░ »
# «   q_0: ───┤ √X ├──┤ Rz(π/2) ├──■──┤ Rz(π) ├─┤ X ├──────────────░───■───░─»
# «        ┌──┴────┴─┐└─────────┘┌─┴─┐├───────┴┐├───┴┐┌──────────┐ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(π/2) ├───────────┤ X ├┤ Rz(-π) ├┤ √X ├┤ Rz(-π/2) ├─░─┤ X ├─░─»
# «        └─────────┘           └───┘└────────┘└────┘└──────────┘ ░ └───┘ ░ »
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌────┐┌─────────┐     ┌───┐┌─────────┐┌────┐┌────────┐ ░       ░ »
# «   q_0: ┤ √X ├┤ Rz(π/2) ├──■──┤ X ├┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├─░───■───░─»
# «        └────┘└─────────┘┌─┴─┐└─┬─┘├─────────┤├────┤└────────┘ ░ ┌─┴─┐ ░ »
# «   q_1: ─────────────────┤ X ├──■──┤ Rz(π/2) ├┤ √X ├───────────░─┤ X ├─░─»
# «                         └───┘     └─────────┘└────┘           ░ └───┘ ░ »
# «meas: 2/═════════════════════════════════════════════════════════════════»
# «                                                                         »
# «        ┌─────────┐                     ┌───┐┌─────────┐ ┌────┐┌────────┐ ░ »
# «   q_0: ┤ Rz(π/2) ├──────────────────■──┤ X ├┤ Rz(π/2) ├─┤ √X ├┤ Rz(-π) ├─░─»
# «        └┬────────┤┌────┐┌────────┐┌─┴─┐└─┬─┘├─────────┴┐├────┤└────────┘ ░ »
# «   q_1: ─┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├┤ X ├──■──┤ Rz(-π/2) ├┤ √X ├───────────░─»
# «         └────────┘└────┘└────────┘└───┘     └──────────┘└────┘           ░ »
# «meas: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «              ░ ┌─────────┐┌────┐┌─────────┐       ┌────┐  ┌──────────┐»
# «   q_0: ──■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├──■────┤ √X ├──┤ Rz(-π/2) ├»
# «        ┌─┴─┐ ░ ├─────────┤└────┘└─────────┘┌─┴─┐┌─┴────┴─┐└──┬────┬──┘»
# «   q_1: ┤ X ├─░─┤ Rz(π/2) ├─────────────────┤ X ├┤ Rz(-π) ├───┤ √X ├───»
# «        └───┘ ░ └─────────┘                 └───┘└────────┘   └────┘   »
# «meas: 2/═══════════════════════════════════════════════════════════════»
# «                                                                       »
# «                     ░       ░ ┌─────────┐     ┌───┐                  »
# «   q_0: ─────────────░───■───░─┤ Rz(π/2) ├──■──┤ X ├──────────────────»
# «        ┌──────────┐ ░ ┌─┴─┐ ░ └─────────┘┌─┴─┐└─┬─┘┌──────────┐┌────┐»
# «   q_1: ┤ Rz(-π/2) ├─░─┤ X ├─░────────────┤ X ├──■──┤ Rz(-π/2) ├┤ √X ├»
# «        └──────────┘ ░ └───┘ ░            └───┘     └──────────┘└────┘»
# «meas: 2/══════════════════════════════════════════════════════════════»
# «                                                                      »
# «                   ░       ░ ┌─────────┐┌────┐┌────────┐     ┌───┐   ┌────┐  »
# «   q_0: ───────────░───■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├──■──┤ X ├───┤ √X ├──»
# «        ┌────────┐ ░ ┌─┴─┐ ░ └─────────┘└────┘└────────┘┌─┴─┐└─┬─┘┌──┴────┴─┐»
# «   q_1: ┤ Rz(-π) ├─░─┤ X ├─░────────────────────────────┤ X ├──■──┤ Rz(π/2) ├»
# «        └────────┘ ░ └───┘ ░                            └───┘     └─────────┘»
# «meas: 2/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «        ┌──────────┐           ░       ░ ┌─────────┐┌────┐┌────────┐     ┌───┐»
# «   q_0: ┤ Rz(-π/2) ├───────────░───■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├──■──┤ X ├»
# «        └──┬────┬──┘┌────────┐ ░ ┌─┴─┐ ░ └┬────────┤├────┤├────────┤┌─┴─┐└─┬─┘»
# «   q_1: ───┤ √X ├───┤ Rz(-π) ├─░─┤ X ├─░──┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├┤ X ├──■──»
# «           └────┘   └────────┘ ░ └───┘ ░  └────────┘└────┘└────────┘└───┘     »
# «meas: 2/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌─────────┐   ┌────┐   ░       ░ ┌─────────┐   ┌────┐  ┌─────────┐»
# «   q_0: ┤ Rz(π/2) ├───┤ √X ├───░───■───░─┤ Rz(π/2) ├───┤ √X ├──┤ Rz(π/2) ├»
# «        └──┬────┬─┘┌──┴────┴─┐ ░ ┌─┴─┐ ░ └──┬────┬─┘┌──┴────┴─┐└─────────┘»
# «   q_1: ───┤ √X ├──┤ Rz(π/2) ├─░─┤ X ├─░────┤ √X ├──┤ Rz(π/2) ├───────────»
# «           └────┘  └─────────┘ ░ └───┘ ░    └────┘  └─────────┘           »
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «             ┌─────────┐ ┌────┐           ░       ░ ┌─────────┐      »
# «   q_0: ──■──┤ Rz(π/2) ├─┤ √X ├───────────░───■───░─┤ Rz(π/2) ├──────»
# «        ┌─┴─┐├─────────┴┐├────┤┌────────┐ ░ ┌─┴─┐ ░ ├─────────┤┌────┐»
# «   q_1: ┤ X ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(-π) ├─░─┤ X ├─░─┤ Rz(π/2) ├┤ √X ├»
# «        └───┘└──────────┘└────┘└────────┘ ░ └───┘ ░ └─────────┘└────┘»
# «meas: 2/═════════════════════════════════════════════════════════════»
# «                                                                     »
# «                       ┌─────────┐   ┌────┐   ┌────────┐ ░       ░           »
# «   q_0: ────────────■──┤ Rz(π/2) ├───┤ √X ├───┤ Rz(-π) ├─░───■───░───────────»
# «        ┌────────┐┌─┴─┐└──┬────┬─┘┌──┴────┴──┐└────────┘ ░ ┌─┴─┐ ░ ┌────────┐»
# «   q_1: ┤ Rz(-π) ├┤ X ├───┤ √X ├──┤ Rz(-π/2) ├───────────░─┤ X ├─░─┤ Rz(-π) ├»
# «        └────────┘└───┘   └────┘  └──────────┘           ░ └───┘ ░ └────────┘»
# «meas: 2/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                           ░       ░                                »
# «   q_0: ───────────────────░───■───░─────────────────────────────■──»
# «        ┌────┐┌──────────┐ ░ ┌─┴─┐ ░ ┌────────┐┌────┐┌────────┐┌─┴─┐»
# «   q_1: ┤ √X ├┤ Rz(-π/2) ├─░─┤ X ├─░─┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├┤ X ├»
# «        └────┘└──────────┘ ░ └───┘ ░ └────────┘└────┘└────────┘└───┘»
# «meas: 2/════════════════════════════════════════════════════════════»
# «                                                                    »
# «        ┌──────────┐┌────┐             ░       ░ ┌─────────┐                »
# «   q_0: ┤ Rz(-π/2) ├┤ √X ├─────────────░───■───░─┤ Rz(π/2) ├─────────────■──»
# «        └┬────────┬┘├────┤┌──────────┐ ░ ┌─┴─┐ ░ └──┬────┬─┘┌─────────┐┌─┴─┐»
# «   q_1: ─┤ Rz(-π) ├─┤ √X ├┤ Rz(-π/2) ├─░─┤ X ├─░────┤ √X ├──┤ Rz(π/2) ├┤ X ├»
# «         └────────┘ └────┘└──────────┘ ░ └───┘ ░    └────┘  └─────────┘└───┘»
# «meas: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «        ┌───┐┌────────┐┌────┐┌─────────┐ ░       ░ ┌────┐┌─────────┐     ┌───┐»
# «   q_0: ┤ X ├┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├─░───■───░─┤ √X ├┤ Rz(π/2) ├──■──┤ X ├»
# «        └─┬─┘└─┬───┬──┘└────┘└─────────┘ ░ ┌─┴─┐ ░ ├────┤├─────────┤┌─┴─┐└─┬─┘»
# «   q_1: ──■────┤ X ├─────────────────────░─┤ X ├─░─┤ √X ├┤ Rz(π/2) ├┤ X ├──■──»
# «               └───┘                     ░ └───┘ ░ └────┘└─────────┘└───┘     »
# «meas: 2/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌────────┐┌────┐┌─────────┐ ░       ░ ┌────────┐   ┌────┐  ┌────────┐»
# «   q_0: ┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├─░───■───░─┤ Rz(-π) ├───┤ √X ├──┤ Rz(-π) ├»
# «        └────────┘└────┘└─────────┘ ░ ┌─┴─┐ ░ └─┬────┬─┘┌──┴────┴─┐└────────┘»
# «   q_1: ────────────────────────────░─┤ X ├─░───┤ √X ├──┤ Rz(π/2) ├──────────»
# «                                    ░ └───┘ ░   └────┘  └─────────┘          »
# «meas: 2/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «             ┌───┐  ┌────┐ ┌─────────┐ ░       ░                       ┌───┐»
# «   q_0: ──■──┤ X ├──┤ √X ├─┤ Rz(π/2) ├─░───■───░────────────────────■──┤ X ├»
# «        ┌─┴─┐└─┬─┘┌─┴────┴┐└──┬───┬──┘ ░ ┌─┴─┐ ░ ┌────┐┌─────────┐┌─┴─┐└─┬─┘»
# «   q_1: ┤ X ├──■──┤ Rz(π) ├───┤ X ├────░─┤ X ├─░─┤ √X ├┤ Rz(π/2) ├┤ X ├──■──»
# «        └───┘     └───────┘   └───┘    ░ └───┘ ░ └────┘└─────────┘└───┘     »
# «meas: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «        ┌────┐┌─────────┐  ░       ░ ┌─────────┐     ┌───┐┌──────────┐┌────┐»
# «   q_0: ┤ √X ├┤ Rz(π/2) ├──░───■───░─┤ Rz(π/2) ├──■──┤ X ├┤ Rz(-π/2) ├┤ √X ├»
# «        ├────┤├─────────┴┐ ░ ┌─┴─┐ ░ ├─────────┤┌─┴─┐└─┬─┘├─────────┬┘├────┤»
# «   q_1: ┤ √X ├┤ Rz(-π/2) ├─░─┤ X ├─░─┤ Rz(π/2) ├┤ X ├──■──┤ Rz(π/2) ├─┤ √X ├»
# «        └────┘└──────────┘ ░ └───┘ ░ └─────────┘└───┘     └─────────┘ └────┘»
# «meas: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «        ┌────────┐ ░       ░       ░       ░ ┌─────────┐     ┌───────┐»
# «   q_0: ┤ Rz(-π) ├─░───■───░───────░───■───░─┤ Rz(π/2) ├──■──┤ Rz(π) ├»
# «        ├────────┤ ░ ┌─┴─┐ ░ ┌───┐ ░ ┌─┴─┐ ░ └─────────┘┌─┴─┐└─┬────┬┘»
# «   q_1: ┤ Rz(-π) ├─░─┤ X ├─░─┤ X ├─░─┤ X ├─░────────────┤ X ├──┤ √X ├─»
# «        └────────┘ ░ └───┘ ░ └───┘ ░ └───┘ ░            └───┘  └────┘ »
# «meas: 2/══════════════════════════════════════════════════════════════»
# «                                                                      »
# «                     ░       ░    ┌────┐  ┌─────────┐                ┌───┐»
# «   q_0: ─────────────░───■───░────┤ √X ├──┤ Rz(π/2) ├─────────────■──┤ X ├»
# «        ┌──────────┐ ░ ┌─┴─┐ ░ ┌──┴────┴─┐└──┬────┬─┘┌─────────┐┌─┴─┐└─┬─┘»
# «   q_1: ┤ Rz(-π/2) ├─░─┤ X ├─░─┤ Rz(π/2) ├───┤ √X ├──┤ Rz(π/2) ├┤ X ├──■──»
# «        └──────────┘ ░ └───┘ ░ └─────────┘   └────┘  └─────────┘└───┘     »
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «         ┌───────┐                   ░       ░  ┌────────┐┌────┐┌────────┐»
# «   q_0: ─┤ Rz(π) ├───────────────────░───■───░──┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├»
# «        ┌┴───────┴─┐┌────┐┌────────┐ ░ ┌─┴─┐ ░ ┌┴────────┤└────┘└────────┘»
# «   q_1: ┤ Rz(-π/2) ├┤ √X ├┤ Rz(-π) ├─░─┤ X ├─░─┤ Rz(π/2) ├────────────────»
# «        └──────────┘└────┘└────────┘ ░ └───┘ ░ └─────────┘                »
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «             ┌───┐ ░       ░ ┌─────────┐   ┌────┐  ┌────────┐     ┌───┐┌────┐»
# «   q_0: ──■──┤ X ├─░───■───░─┤ Rz(π/2) ├───┤ √X ├──┤ Rz(-π) ├──■──┤ X ├┤ √X ├»
# «        ┌─┴─┐└───┘ ░ ┌─┴─┐ ░ └──┬────┬─┘┌──┴────┴─┐└────────┘┌─┴─┐└─┬─┘└────┘»
# «   q_1: ┤ X ├──────░─┤ X ├─░────┤ √X ├──┤ Rz(π/2) ├──────────┤ X ├──■────────»
# «        └───┘      ░ └───┘ ░    └────┘  └─────────┘          └───┘           »
# «meas: 2/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «        ┌──────────┐ ░       ░ ┌────────┐   ┌────┐  ┌────────┐       ┌────┐  »
# «   q_0: ┤ Rz(-π/2) ├─░───■───░─┤ Rz(-π) ├───┤ √X ├──┤ Rz(-π) ├──■────┤ √X ├──»
# «        └──────────┘ ░ ┌─┴─┐ ░ └─┬────┬─┘┌──┴────┴─┐└────────┘┌─┴─┐┌─┴────┴─┐»
# «   q_1: ─────────────░─┤ X ├─░───┤ √X ├──┤ Rz(π/2) ├──────────┤ X ├┤ Rz(-π) ├»
# «                     ░ └───┘ ░   └────┘  └─────────┘          └───┘└────────┘»
# «meas: 2/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «        ┌─────────┐             ░       ░ ┌─────────┐                ┌───┐»
# «   q_0: ┤ Rz(π/2) ├─────────────░───■───░─┤ Rz(π/2) ├─────────────■──┤ X ├»
# «        └──┬────┬─┘┌──────────┐ ░ ┌─┴─┐ ░ └──┬────┬─┘┌─────────┐┌─┴─┐└─┬─┘»
# «   q_1: ───┤ √X ├──┤ Rz(-π/2) ├─░─┤ X ├─░────┤ √X ├──┤ Rz(π/2) ├┤ X ├──■──»
# «           └────┘  └──────────┘ ░ └───┘ ░    └────┘  └─────────┘└───┘     »
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌─────────┐ ┌────┐ ░       ░ ┌─────────┐┌────┐┌────────┐     »
# «   q_0: ┤ Rz(π/2) ├─┤ √X ├─░───■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├──■──»
# «        ├─────────┴┐├────┤ ░ ┌─┴─┐ ░ └─────────┘└────┘└────────┘┌─┴─┐»
# «   q_1: ┤ Rz(-π/2) ├┤ √X ├─░─┤ X ├─░────────────────────────────┤ X ├»
# «        └──────────┘└────┘ ░ └───┘ ░                            └───┘»
# «meas: 2/═════════════════════════════════════════════════════════════»
# «                                                                     »
# «         ┌────────┐┌────┐┌──────────┐ ░       ░ ┌─────────┐   ┌────┐  »
# «   q_0: ─┤ Rz(-π) ├┤ √X ├┤ Rz(-π/2) ├─░───■───░─┤ Rz(π/2) ├───┤ √X ├──»
# «        ┌┴────────┤├────┤└┬────────┬┘ ░ ┌─┴─┐ ░ └──┬────┬─┘┌──┴────┴─┐»
# «   q_1: ┤ Rz(π/2) ├┤ √X ├─┤ Rz(-π) ├──░─┤ X ├─░────┤ √X ├──┤ Rz(π/2) ├»
# «        └─────────┘└────┘ └────────┘  ░ └───┘ ░    └────┘  └─────────┘»
# «meas: 2/══════════════════════════════════════════════════════════════»
# «                                                                      »
# «        ┌─────────┐     ┌─────────┐┌────┐ ░       ░ ┌────┐┌─────────┐     »
# «   q_0: ┤ Rz(π/2) ├──■──┤ Rz(π/2) ├┤ √X ├─░───■───░─┤ √X ├┤ Rz(π/2) ├──■──»
# «        └─────────┘┌─┴─┐└─────────┘└────┘ ░ ┌─┴─┐ ░ └────┘└─────────┘┌─┴─┐»
# «   q_1: ───────────┤ X ├──────────────────░─┤ X ├─░──────────────────┤ X ├»
# «                   └───┘                  ░ └───┘ ░                  └───┘»
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌───┐┌────────┐┌────┐┌──────────┐ ░       ░    ┌────┐  ┌─────────┐»
# «   q_0: ┤ X ├┤ Rz(-π) ├┤ √X ├┤ Rz(-π/2) ├─░───■───░────┤ √X ├──┤ Rz(π/2) ├»
# «        └─┬─┘├────────┤├────┤├─────────┬┘ ░ ┌─┴─┐ ░ ┌──┴────┴─┐└──┬────┬─┘»
# «   q_1: ──■──┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├──░─┤ X ├─░─┤ Rz(π/2) ├───┤ √X ├──»
# «             └────────┘└────┘└─────────┘  ░ └───┘ ░ └─────────┘   └────┘  »
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «                        ┌───┐┌─────────┐ ┌────┐┌────────┐ ░       ░ »
# «   q_0: ─────────────■──┤ X ├┤ Rz(π/2) ├─┤ √X ├┤ Rz(-π) ├─░───■───░─»
# «        ┌─────────┐┌─┴─┐└─┬─┘├─────────┴┐├────┤└────────┘ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(π/2) ├┤ X ├──■──┤ Rz(-π/2) ├┤ √X ├───────────░─┤ X ├─░─»
# «        └─────────┘└───┘     └──────────┘└────┘           ░ └───┘ ░ »
# «meas: 2/════════════════════════════════════════════════════════════»
# «                                                                    »
# «        ┌─────────┐┌────┐┌────────┐     ┌───┐┌─────────┐┌────┐ ░       ░ »
# «   q_0: ┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├──■──┤ X ├┤ Rz(π/2) ├┤ √X ├─░───■───░─»
# «        └─────────┘└────┘└────────┘┌─┴─┐└─┬─┘├─────────┤├────┤ ░ ┌─┴─┐ ░ »
# «   q_1: ───────────────────────────┤ X ├──■──┤ Rz(π/2) ├┤ √X ├─░─┤ X ├─░─»
# «                                   └───┘     └─────────┘└────┘ ░ └───┘ ░ »
# «meas: 2/═════════════════════════════════════════════════════════════════»
# «                                                                         »
# «        ┌─────────┐┌────┐┌─────────┐     ┌───┐           ░       ░ ┌─────────┐»
# «   q_0: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├──■──┤ X ├──■────────░───■───░─┤ Rz(π/2) ├»
# «        ├─────────┤├────┤├─────────┤┌─┴─┐└─┬─┘┌─┴─┐┌───┐ ░ ┌─┴─┐ ░ ├─────────┤»
# «   q_1: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ X ├──■──┤ X ├┤ X ├─░─┤ X ├─░─┤ Rz(π/2) ├»
# «        └─────────┘└────┘└─────────┘└───┘     └───┘└───┘ ░ └───┘ ░ └─────────┘»
# «meas: 2/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌────┐┌────────┐     ┌───┐                   ░       ░ ┌─────────┐»
# «   q_0: ┤ √X ├┤ Rz(-π) ├──■──┤ X ├───────────────────░───■───░─┤ Rz(π/2) ├»
# «        └────┘└────────┘┌─┴─┐└─┬─┘┌──────────┐┌────┐ ░ ┌─┴─┐ ░ ├─────────┤»
# «   q_1: ────────────────┤ X ├──■──┤ Rz(-π/2) ├┤ √X ├─░─┤ X ├─░─┤ Rz(π/2) ├»
# «                        └───┘     └──────────┘└────┘ ░ └───┘ ░ └─────────┘»
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌────┐ ┌────────┐     ┌───┐┌──────────┐┌────┐┌────────┐ ░       ░ »
# «   q_0: ┤ √X ├─┤ Rz(-π) ├──■──┤ X ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(-π) ├─░───■───░─»
# «        ├────┤┌┴────────┤┌─┴─┐└─┬─┘├─────────┬┘├────┤└────────┘ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ √X ├┤ Rz(π/2) ├┤ X ├──■──┤ Rz(π/2) ├─┤ √X ├───────────░─┤ X ├─░─»
# «        └────┘└─────────┘└───┘     └─────────┘ └────┘           ░ └───┘ ░ »
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌─────────┐     ┌────────┐┌────┐┌──────────┐ ░       ░    ┌────┐  »
# «   q_0: ┤ Rz(π/2) ├──■──┤ Rz(-π) ├┤ √X ├┤ Rz(-π/2) ├─░───■───░────┤ √X ├──»
# «        ├─────────┤┌─┴─┐├───────┬┘└────┘└──────────┘ ░ ┌─┴─┐ ░ ┌──┴────┴─┐»
# «   q_1: ┤ Rz(π/2) ├┤ X ├┤ Rz(π) ├────────────────────░─┤ X ├─░─┤ Rz(π/2) ├»
# «        └─────────┘└───┘└───────┘                    ░ └───┘ ░ └─────────┘»
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌─────────┐     ┌───┐   ┌───┐           ░       ░  ┌────────┐┌────┐»
# «   q_0: ┤ Rz(π/2) ├──■──┤ X ├───┤ X ├───────────░───■───░──┤ Rz(-π) ├┤ √X ├»
# «        └─────────┘┌─┴─┐└─┬─┘┌──┴───┴───┐┌────┐ ░ ┌─┴─┐ ░ ┌┴────────┤├────┤»
# «   q_1: ───────────┤ X ├──■──┤ Rz(-π/2) ├┤ √X ├─░─┤ X ├─░─┤ Rz(π/2) ├┤ √X ├»
# «                   └───┘     └──────────┘└────┘ ░ └───┘ ░ └─────────┘└────┘»
# «meas: 2/═══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «        ┌────────┐     ┌───┐┌──────────┐┌────┐ ┌────────┐  ░       ░ »
# «   q_0: ┤ Rz(-π) ├──■──┤ X ├┤ Rz(-π/2) ├┤ √X ├─┤ Rz(-π) ├──░───■───░─»
# «        ├────────┤┌─┴─┐└─┬─┘└┬────────┬┘├────┤┌┴────────┴┐ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(-π) ├┤ X ├──■───┤ Rz(-π) ├─┤ √X ├┤ Rz(-π/2) ├─░─┤ X ├─░─»
# «        └────────┘└───┘      └────────┘ └────┘└──────────┘ ░ └───┘ ░ »
# «meas: 2/═════════════════════════════════════════════════════════════»
# «                                                                     »
# «        ┌─────────┐┌────┐┌─────────┐     ┌───┐┌───────┐ ░       ░ ┌─────────┐»
# «   q_0: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├──■──┤ X ├┤ Rz(π) ├─░───■───░─┤ Rz(π/2) ├»
# «        ├─────────┤└────┘└─────────┘┌─┴─┐└─┬─┘└─┬───┬─┘ ░ ┌─┴─┐ ░ └┬────────┤»
# «   q_1: ┤ Rz(π/2) ├─────────────────┤ X ├──■────┤ X ├───░─┤ X ├─░──┤ Rz(-π) ├»
# «        └─────────┘                 └───┘       └───┘   ░ └───┘ ░  └────────┘»
# «meas: 2/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «        ┌────┐┌────────┐     ┌──────────┐┌────┐┌────────┐ ░       ░ »
# «   q_0: ┤ √X ├┤ Rz(-π) ├──■──┤ Rz(-π/2) ├┤ √X ├┤ Rz(-π) ├─░───■───░─»
# «        ├────┤├────────┤┌─┴─┐├──────────┤├────┤├────────┤ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ √X ├┤ Rz(-π) ├┤ X ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(-π) ├─░─┤ X ├─░─»
# «        └────┘└────────┘└───┘└──────────┘└────┘└────────┘ ░ └───┘ ░ »
# «meas: 2/════════════════════════════════════════════════════════════»
# «                                                                    »
# «           ┌────┐  ┌─────────┐               ┌───┐┌──────────┐┌────┐»
# «   q_0: ───┤ √X ├──┤ Rz(π/2) ├────────────■──┤ X ├┤ Rz(-π/2) ├┤ √X ├»
# «        ┌──┴────┴─┐└──┬────┬─┘┌────────┐┌─┴─┐└─┬─┘└┬────────┬┘├────┤»
# «   q_1: ┤ Rz(π/2) ├───┤ √X ├──┤ Rz(-π) ├┤ X ├──■───┤ Rz(-π) ├─┤ √X ├»
# «        └─────────┘   └────┘  └────────┘└───┘      └────────┘ └────┘»
# «meas: 2/════════════════════════════════════════════════════════════»
# «                                                                    »
# «         ┌────────┐  ░       ░ ┌─────────┐┌────┐┌─────────┐     ┌─────────┐»
# «   q_0: ─┤ Rz(-π) ├──░───■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├──■──┤ Rz(π/2) ├»
# «        ┌┴────────┴┐ ░ ┌─┴─┐ ░ └┬────────┤├────┤└┬────────┤┌─┴─┐├─────────┤»
# «   q_1: ┤ Rz(-π/2) ├─░─┤ X ├─░──┤ Rz(-π) ├┤ √X ├─┤ Rz(-π) ├┤ X ├┤ Rz(π/2) ├»
# «        └──────────┘ ░ └───┘ ░  └────────┘└────┘ └────────┘└───┘└─────────┘»
# «meas: 2/═══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «        ┌────┐┌────────┐ ░       ░ ┌────────┐┌────┐┌────────┐     ┌──────────┐»
# «   q_0: ┤ √X ├┤ Rz(-π) ├─░───■───░─┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├──■──┤ Rz(-π/2) ├»
# «        ├────┤└────────┘ ░ ┌─┴─┐ ░ ├────────┤├────┤├────────┤┌─┴─┐├──────────┤»
# «   q_1: ┤ √X ├───────────░─┤ X ├─░─┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├┤ X ├┤ Rz(-π/2) ├»
# «        └────┘           ░ └───┘ ░ └────────┘└────┘└────────┘└───┘└──────────┘»
# «meas: 2/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌────┐┌────────┐ ░       ░ ┌─────────┐┌────┐┌────────┐     ┌───┐»
# «   q_0: ┤ √X ├┤ Rz(-π) ├─░───■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├──■──┤ X ├»
# «        ├────┤└────────┘ ░ ┌─┴─┐ ░ ├─────────┤├────┤├────────┤┌─┴─┐└─┬─┘»
# «   q_1: ┤ √X ├───────────░─┤ X ├─░─┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├┤ X ├──■──»
# «        └────┘           ░ └───┘ ░ └─────────┘└────┘└────────┘└───┘     »
# «meas: 2/════════════════════════════════════════════════════════════════»
# «                                                                        »
# «                                     ░       ░   ┌────┐  ┌─────────┐          »
# «   q_0: ─────────────────────────────░───■───░───┤ √X ├──┤ Rz(π/2) ├──────────»
# «        ┌────────┐┌────┐┌──────────┐ ░ ┌─┴─┐ ░ ┌─┴────┴─┐└──┬────┬─┘┌────────┐»
# «   q_1: ┤ Rz(-π) ├┤ √X ├┤ Rz(-π/2) ├─░─┤ X ├─░─┤ Rz(-π) ├───┤ √X ├──┤ Rz(-π) ├»
# «        └────────┘└────┘└──────────┘ ░ └───┘ ░ └────────┘   └────┘  └────────┘»
# «meas: 2/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «              ┌───────┐        ░       ░ ┌─────────┐┌────┐┌─────────┐     »
# «   q_0: ──■───┤ Rz(π) ├────────░───■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├──■──»
# «        ┌─┴─┐┌┴───────┴┐┌────┐ ░ ┌─┴─┐ ░ └─────────┘└────┘└─────────┘┌─┴─┐»
# «   q_1: ┤ X ├┤ Rz(π/2) ├┤ √X ├─░─┤ X ├─░─────────────────────────────┤ X ├»
# «        └───┘└─────────┘└────┘ ░ └───┘ ░                             └───┘»
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌───┐     ┌───────┐┌───┐ ░       ░ ┌─────────┐      ┌───────┐       »
# «   q_0: ┤ X ├──■──┤ Rz(π) ├┤ X ├─░───■───░─┤ Rz(π/2) ├──■───┤ Rz(π) ├───────»
# «        └─┬─┘┌─┴─┐└─┬───┬─┘└───┘ ░ ┌─┴─┐ ░ ├─────────┤┌─┴─┐┌┴───────┴┐┌────┐»
# ...
# «meas: 2/════════════════════════════════════════════════════════════»
# «                                                                    »
# «                        ┌────┐┌──────────┐ ░       ░    ┌────┐  ┌─────────┐»
# «   q_0: ─────────────■──┤ √X ├┤ Rz(-π/2) ├─░───■───░────┤ √X ├──┤ Rz(π/2) ├»
# «        ┌─────────┐┌─┴─┐├────┤├─────────┬┘ ░ ┌─┴─┐ ░ ┌──┴────┴─┐└─────────┘»
# «   q_1: ┤ Rz(π/2) ├┤ X ├┤ √X ├┤ Rz(π/2) ├──░─┤ X ├─░─┤ Rz(π/2) ├───────────»
# «        └─────────┘└───┘└────┘└─────────┘  ░ └───┘ ░ └─────────┘           »
# «meas: 2/═══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «              ┌────────┐┌────┐┌─────────┐ ░       ░ ┌─────────┐┌────┐»
# «   q_0: ──■───┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├─░───■───░─┤ Rz(π/2) ├┤ √X ├»
# «        ┌─┴─┐┌┴────────┤├────┤└┬────────┤ ░ ┌─┴─┐ ░ ├─────────┤└────┘»
# «   q_1: ┤ X ├┤ Rz(π/2) ├┤ √X ├─┤ Rz(-π) ├─░─┤ X ├─░─┤ Rz(π/2) ├──────»
# «        └───┘└─────────┘└────┘ └────────┘ ░ └───┘ ░ └─────────┘      »
# «meas: 2/═════════════════════════════════════════════════════════════»
# «                                                                     »
# «        ┌─────────┐     ┌─────────┐ ┌────┐           ░       ░ ┌──────────┐»
# «   q_0: ┤ Rz(π/2) ├──■──┤ Rz(π/2) ├─┤ √X ├───────────░───■───░─┤ Rz(-π/2) ├»
# «        └─────────┘┌─┴─┐├─────────┴┐├────┤┌────────┐ ░ ┌─┴─┐ ░ └┬────────┬┘»
# «   q_1: ───────────┤ X ├┤ Rz(-π/2) ├┤ √X ├┤ Rz(-π) ├─░─┤ X ├─░──┤ Rz(-π) ├─»
# «                   └───┘└──────────┘└────┘└────────┘ ░ └───┘ ░  └────────┘ »
# «meas: 2/═══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «        ┌────┐┌─────────┐  ░       ░ ┌─────────┐┌────┐┌─────────┐     ┌───┐»
# «   q_0: ┤ √X ├┤ Rz(π/2) ├──░───■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├──■──┤ X ├»
# «        ├────┤├─────────┴┐ ░ ┌─┴─┐ ░ └─────────┘└────┘└─────────┘┌─┴─┐└─┬─┘»
# «   q_1: ┤ √X ├┤ Rz(-π/2) ├─░─┤ X ├─░─────────────────────────────┤ X ├──■──»
# «        └────┘└──────────┘ ░ └───┘ ░                             └───┘     »
# «meas: 2/═══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «        ┌────────┐┌────┐┌─────────┐ ░       ░                       ┌───┐»
# «   q_0: ┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├─░───■───░────────────────────■──┤ X ├»
# «        ├────────┤├────┤├─────────┤ ░ ┌─┴─┐ ░ ┌────┐┌─────────┐┌─┴─┐└─┬─┘»
# «   q_1: ┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├─░─┤ X ├─░─┤ √X ├┤ Rz(π/2) ├┤ X ├──■──»
# «        └────────┘└────┘└─────────┘ ░ └───┘ ░ └────┘└─────────┘└───┘     »
# «meas: 2/═════════════════════════════════════════════════════════════════»
# «                                                                         »
# «                  ░       ░ ┌─────────┐┌────┐┌────────┐     ┌───┐┌───────┐»
# «   q_0: ──────────░───■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├──■──┤ X ├┤ Rz(π) ├»
# «        ┌───────┐ ░ ┌─┴─┐ ░ ├─────────┤└────┘└────────┘┌─┴─┐└─┬─┘└───────┘»
# «   q_1: ┤ Rz(π) ├─░─┤ X ├─░─┤ Rz(π/2) ├────────────────┤ X ├──■───────────»
# «        └───────┘ ░ └───┘ ░ └─────────┘                └───┘              »
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌───┐ ░       ░ ┌─────────┐                ┌───┐┌───────┐ ░       ░ »
# «   q_0: ┤ X ├─░───■───░─┤ Rz(π/2) ├─────────────■──┤ X ├┤ Rz(π) ├─░───■───░─»
# «        └───┘ ░ ┌─┴─┐ ░ └──┬────┬─┘┌─────────┐┌─┴─┐└─┬─┘└─┬───┬─┘ ░ ┌─┴─┐ ░ »
# «   q_1: ──────░─┤ X ├─░────┤ √X ├──┤ Rz(π/2) ├┤ X ├──■────┤ X ├───░─┤ X ├─░─»
# «              ░ └───┘ ░    └────┘  └─────────┘└───┘       └───┘   ░ └───┘ ░ »
# «meas: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «        ┌────┐┌─────────┐     ┌────┐┌─────────┐ ░       ░                 »
# «   q_0: ┤ √X ├┤ Rz(π/2) ├──■──┤ √X ├┤ Rz(π/2) ├─░───■───░─────────────────»
# «        ├────┤├─────────┤┌─┴─┐└────┘└─────────┘ ░ ┌─┴─┐ ░ ┌────────┐┌────┐»
# «   q_1: ┤ √X ├┤ Rz(π/2) ├┤ X ├──────────────────░─┤ X ├─░─┤ Rz(-π) ├┤ √X ├»
# «        └────┘└─────────┘└───┘                  ░ └───┘ ░ └────────┘└────┘»
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «                       ┌───┐┌────────┐   ┌────┐   ┌──────────┐ ░       ░ »
# «   q_0: ────────────■──┤ X ├┤ Rz(-π) ├───┤ √X ├───┤ Rz(-π/2) ├─░───■───░─»
# «        ┌────────┐┌─┴─┐└─┬─┘└─┬────┬─┘┌──┴────┴──┐└──────────┘ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ Rz(-π) ├┤ X ├──■────┤ √X ├──┤ Rz(-π/2) ├─────────────░─┤ X ├─░─»
# «        └────────┘└───┘       └────┘  └──────────┘             ░ └───┘ ░ »
# «meas: 2/═════════════════════════════════════════════════════════════════»
# «                                                                         »
# «         ┌────────┐┌────┐ ┌────────┐     ┌───┐ ┌────────┐ ┌────┐┌──────────┐»
# «   q_0: ─┤ Rz(-π) ├┤ √X ├─┤ Rz(-π) ├──■──┤ X ├─┤ Rz(-π) ├─┤ √X ├┤ Rz(-π/2) ├»
# «        ┌┴────────┤├────┤┌┴────────┤┌─┴─┐└─┬─┘┌┴────────┴┐├────┤└┬────────┬┘»
# «   q_1: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ X ├──■──┤ Rz(-π/2) ├┤ √X ├─┤ Rz(-π) ├─»
# «        └─────────┘└────┘└─────────┘└───┘     └──────────┘└────┘ └────────┘ »
# «meas: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «         ░       ░ ┌─────────┐                     ┌───┐┌────────┐┌────┐»
# «   q_0: ─░───■───░─┤ Rz(π/2) ├──────────────────■──┤ X ├┤ Rz(-π) ├┤ √X ├»
# «         ░ ┌─┴─┐ ░ ├─────────┤┌────┐┌────────┐┌─┴─┐└─┬─┘└────────┘└────┘»
# «   q_1: ─░─┤ X ├─░─┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├┤ X ├──■──────────────────»
# «         ░ └───┘ ░ └─────────┘└────┘└────────┘└───┘                     »
# «meas: 2/════════════════════════════════════════════════════════════════»
# «                                                                        »
# «        ┌──────────┐ ░       ░ ┌─────────┐                     ┌──────────┐»
# «   q_0: ┤ Rz(-π/2) ├─░───■───░─┤ Rz(π/2) ├──────────────────■──┤ Rz(-π/2) ├»
# «        └──────────┘ ░ ┌─┴─┐ ░ └┬────────┤┌────┐┌────────┐┌─┴─┐└┬───────┬─┘»
# «   q_1: ─────────────░─┤ X ├─░──┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├┤ X ├─┤ Rz(π) ├──»
# «                     ░ └───┘ ░  └────────┘└────┘└────────┘└───┘ └───────┘  »
# «meas: 2/═══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «        ┌────┐ ░       ░ ┌─────────┐┌────┐┌─────────┐     ┌────────┐┌────┐»
# «   q_0: ┤ √X ├─░───■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├──■──┤ Rz(-π) ├┤ √X ├»
# «        ├───┬┘ ░ ┌─┴─┐ ░ └─────────┘└────┘└─────────┘┌─┴─┐└─┬───┬──┘└────┘»
# «   q_1: ┤ X ├──░─┤ X ├─░─────────────────────────────┤ X ├──┤ X ├─────────»
# «        └───┘  ░ └───┘ ░                             └───┘  └───┘         »
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌──────────┐ ░       ░ ┌────────┐┌────┐┌────────┐     ┌───┐      »
# «   q_0: ┤ Rz(-π/2) ├─░───■───░─┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├──■──┤ X ├──────»
# «        └──────────┘ ░ ┌─┴─┐ ░ └────────┘└────┘└────────┘┌─┴─┐└─┬─┘┌────┐»
# «   q_1: ─────────────░─┤ X ├─░───────────────────────────┤ X ├──■──┤ √X ├»
# «                     ░ └───┘ ░                           └───┘     └────┘»
# «meas: 2/═════════════════════════════════════════════════════════════════»
# «                                                                         »
# «                     ░       ░ ┌─────────┐┌────┐ ┌────────┐        ┌────┐  »
# «   q_0: ─────────────░───■───░─┤ Rz(π/2) ├┤ √X ├─┤ Rz(-π) ├──■─────┤ √X ├──»
# «        ┌──────────┐ ░ ┌─┴─┐ ░ ├─────────┤├────┤┌┴────────┤┌─┴─┐┌──┴────┴─┐»
# «   q_1: ┤ Rz(-π/2) ├─░─┤ X ├─░─┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ X ├┤ Rz(π/2) ├»
# «        └──────────┘ ░ └───┘ ░ └─────────┘└────┘└─────────┘└───┘└─────────┘»
# «meas: 2/═══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «        ┌──────────┐ ░       ░ ┌────────┐   ┌────┐  ┌────────┐        ┌───┐   »
# «   q_0: ┤ Rz(-π/2) ├─░───■───░─┤ Rz(-π) ├───┤ √X ├──┤ Rz(-π) ├──■─────┤ X ├───»
# «        └──┬────┬──┘ ░ ┌─┴─┐ ░ └─┬────┬─┘┌──┴────┴─┐└────────┘┌─┴─┐┌──┴───┴──┐»
# «   q_1: ───┤ √X ├────░─┤ X ├─░───┤ √X ├──┤ Rz(π/2) ├──────────┤ X ├┤ Rz(π/2) ├»
# «           └────┘    ░ └───┘ ░   └────┘  └─────────┘          └───┘└─────────┘»
# «meas: 2/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «               ░       ░ ┌────┐┌─────────┐     ┌───┐┌────────┐┌────┐»
# «   q_0: ───────░───■───░─┤ √X ├┤ Rz(π/2) ├──■──┤ X ├┤ Rz(-π) ├┤ √X ├»
# «        ┌────┐ ░ ┌─┴─┐ ░ ├────┤├─────────┤┌─┴─┐└─┬─┘└─┬───┬──┘└────┘»
# «   q_1: ┤ √X ├─░─┤ X ├─░─┤ √X ├┤ Rz(π/2) ├┤ X ├──■────┤ X ├─────────»
# «        └────┘ ░ └───┘ ░ └────┘└─────────┘└───┘       └───┘         »
# «meas: 2/════════════════════════════════════════════════════════════»
# «                                                                    »
# «        ┌─────────┐ ░       ░ ┌────────┐┌────┐┌────────┐     ┌────┐»
# «   q_0: ┤ Rz(π/2) ├─░───■───░─┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├──■──┤ √X ├»
# «        └─────────┘ ░ ┌─┴─┐ ░ ├────────┤├────┤├────────┤┌─┴─┐├────┤»
# «   q_1: ────────────░─┤ X ├─░─┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├┤ X ├┤ √X ├»
# «                    ░ └───┘ ░ └────────┘└────┘└────────┘└───┘└────┘»
# «meas: 2/═══════════════════════════════════════════════════════════»
# «                                                                   »
# «        ┌──────────┐ ░       ░ ┌─────────┐   ┌────┐  ┌────────┐     ┌───┐»
# «   q_0: ┤ Rz(-π/2) ├─░───■───░─┤ Rz(π/2) ├───┤ √X ├──┤ Rz(-π) ├──■──┤ X ├»
# «        ├─────────┬┘ ░ ┌─┴─┐ ░ └──┬────┬─┘┌──┴────┴─┐└────────┘┌─┴─┐└─┬─┘»
# «   q_1: ┤ Rz(π/2) ├──░─┤ X ├─░────┤ √X ├──┤ Rz(π/2) ├──────────┤ X ├──■──»
# «        └─────────┘  ░ └───┘ ░    └────┘  └─────────┘          └───┘     »
# «meas: 2/═════════════════════════════════════════════════════════════════»
# «                                                                         »
# «                                     ░       ░ ┌────────┐┌────┐┌─────────┐ ░ »
# «   q_0: ─────────────────────────────░───■───░─┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├─░─»
# «        ┌──────────┐┌────┐┌────────┐ ░ ┌─┴─┐ ░ └────────┘└────┘└─────────┘ ░ »
# «   q_1: ┤ Rz(-π/2) ├┤ √X ├┤ Rz(-π) ├─░─┤ X ├─░─────────────────────────────░─»
# «        └──────────┘└────┘└────────┘ ░ └───┘ ░                             ░ »
# «meas: 2/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «              ░                 ┌───┐  ┌────┐ ┌──────────┐ ░       ░ »
# «   q_0: ──■───░──────────────■──┤ X ├──┤ √X ├─┤ Rz(-π/2) ├─░───■───░─»
# «        ┌─┴─┐ ░ ┌─────────┐┌─┴─┐└─┬─┘┌─┴────┴┐└──────────┘ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ X ├─░─┤ Rz(π/2) ├┤ X ├──■──┤ Rz(π) ├─────────────░─┤ X ├─░─»
# «        └───┘ ░ └─────────┘└───┘     └───────┘             ░ └───┘ ░ »
# «meas: 2/═════════════════════════════════════════════════════════════»
# «                                                                     »
# «        ┌─────────┐┌────┐┌────────┐     ┌───┐             ░       ░ ┌────────┐»
# «   q_0: ┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├──■──┤ X ├─────────────░───■───░─┤ Rz(-π) ├»
# «        └─────────┘└────┘└────────┘┌─┴─┐├───┴┐┌─────────┐ ░ ┌─┴─┐ ░ └─┬────┬─┘»
# «   q_1: ───────────────────────────┤ X ├┤ √X ├┤ Rz(π/2) ├─░─┤ X ├─░───┤ √X ├──»
# «                                   └───┘└────┘└─────────┘ ░ └───┘ ░   └────┘  »
# «meas: 2/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «           ┌────┐  ┌────────┐     ┌─────────┐┌────┐ ░       ░            »
# «   q_0: ───┤ √X ├──┤ Rz(-π) ├──■──┤ Rz(π/2) ├┤ √X ├─░───■───░────────────»
# «        ┌──┴────┴─┐└────────┘┌─┴─┐└┬───────┬┘├───┬┘ ░ ┌─┴─┐ ░ ┌─────────┐»
# «   q_1: ┤ Rz(π/2) ├──────────┤ X ├─┤ Rz(π) ├─┤ X ├──░─┤ X ├─░─┤ Rz(π/2) ├»
# «        └─────────┘          └───┘ └───────┘ └───┘  ░ └───┘ ░ └─────────┘»
# «meas: 2/═════════════════════════════════════════════════════════════════»
# «                                                                         »
# «                              ┌────────┐┌────┐┌─────────┐ ░       ░ »
# «   q_0: ───────────────────■──┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├─░───■───░─»
# «        ┌────┐┌─────────┐┌─┴─┐├───────┬┘└────┘└─────────┘ ░ ┌─┴─┐ ░ »
# «   q_1: ┤ √X ├┤ Rz(π/2) ├┤ X ├┤ Rz(π) ├───────────────────░─┤ X ├─░─»
# «        └────┘└─────────┘└───┘└───────┘                   ░ └───┘ ░ »
# «meas: 2/════════════════════════════════════════════════════════════»
# «                                                                    »
# «         ┌────────┐┌────┐ ┌────────┐        ┌────┐   ┌─────────┐           ░ »
# «   q_0: ─┤ Rz(-π) ├┤ √X ├─┤ Rz(-π) ├──■─────┤ √X ├───┤ Rz(π/2) ├───────────░─»
# «        ┌┴────────┤├────┤┌┴────────┤┌─┴─┐┌──┴────┴──┐└──┬────┬─┘┌────────┐ ░ »
# «   q_1: ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ X ├┤ Rz(-π/2) ├───┤ √X ├──┤ Rz(-π) ├─░─»
# «        └─────────┘└────┘└─────────┘└───┘└──────────┘   └────┘  └────────┘ ░ »
# «meas: 2/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «              ░    ┌────┐  ┌─────────┐     ┌───┐┌─────────┐┌────┐            »
# «   q_0: ──■───░────┤ √X ├──┤ Rz(π/2) ├──■──┤ X ├┤ Rz(π/2) ├┤ √X ├────────────»
# «        ┌─┴─┐ ░ ┌──┴────┴─┐└─────────┘┌─┴─┐└─┬─┘└┬────────┤├────┤┌──────────┐»
# «   q_1: ┤ X ├─░─┤ Rz(π/2) ├───────────┤ X ├──■───┤ Rz(-π) ├┤ √X ├┤ Rz(-π/2) ├»
# «        └───┘ ░ └─────────┘           └───┘      └────────┘└────┘└──────────┘»
# «meas: 2/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «         ░       ░ ┌─────────┐                     ┌───┐ ┌────────┐ ┌────┐»
# «   q_0: ─░───■───░─┤ Rz(π/2) ├──────────────────■──┤ X ├─┤ Rz(-π) ├─┤ √X ├»
# «         ░ ┌─┴─┐ ░ └┬────────┤┌────┐┌────────┐┌─┴─┐└─┬─┘┌┴────────┴┐├────┤»
# «   q_1: ─░─┤ X ├─░──┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├┤ X ├──■──┤ Rz(-π/2) ├┤ √X ├»
# «         ░ └───┘ ░  └────────┘└────┘└────────┘└───┘     └──────────┘└────┘»
# «meas: 2/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌─────────┐ ░       ░ ┌────┐┌─────────┐        ┌───┐         »
# «   q_0: ┤ Rz(π/2) ├─░───■───░─┤ √X ├┤ Rz(π/2) ├──■─────┤ X ├─────────»
# «        └┬────────┤ ░ ┌─┴─┐ ░ ├────┤├─────────┤┌─┴─┐┌──┴───┴──┐┌────┐»
# «   q_1: ─┤ Rz(-π) ├─░─┤ X ├─░─┤ √X ├┤ Rz(π/2) ├┤ X ├┤ Rz(π/2) ├┤ √X ├»
# «         └────────┘ ░ └───┘ ░ └────┘└─────────┘└───┘└─────────┘└────┘»
# «meas: 2/═════════════════════════════════════════════════════════════»
# «                                                                     »
# «                   ░       ░ ┌─────────┐┌────┐┌────────┐     ┌───┐┌──────────┐»
# «   q_0: ───────────░───■───░─┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├──■──┤ X ├┤ Rz(-π/2) ├»
# «        ┌────────┐ ░ ┌─┴─┐ ░ ├─────────┤├────┤├────────┤┌─┴─┐└─┬─┘├─────────┬┘»
# «   q_1: ┤ Rz(-π) ├─░─┤ X ├─░─┤ Rz(π/2) ├┤ √X ├┤ Rz(-π) ├┤ X ├──■──┤ Rz(π/2) ├─»
# «        └────────┘ ░ └───┘ ░ └─────────┘└────┘└────────┘└───┘     └─────────┘ »
# «meas: 2/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌────┐┌────────┐ ░ ┌─┐
# «   q_0: ┤ √X ├┤ Rz(-π) ├─░─┤M├───
# «        ├────┤├────────┤ ░ └╥┘┌─┐
# «   q_1: ┤ √X ├┤ Rz(-π) ├─░──╫─┤M├
# «        └────┘└────────┘ ░  ║ └╥┘
# «meas: 2/════════════════════╩══╩═
# «                            0  1

# %% [markdown]
# # Simulation with noise
#
# the 'depolarization channel' have been chosen since it is convinant to verify the RB method with it:
#
# $ \Lambda(\rho) = p\rho + (1 - p)I/d   $
#
# where $d$ is the Hilbert dimension
#
# and the infidelity or error rate of it is:
#
# $ r = (d-1)(1-p)/d $

# %%
# Error probabilities
prob_x = 0.001  # 1-qubit x gate 
prob_z = 0  # 1-qubit gate virtual z gate
prob_2 = 0.01  # 2-qubit gate


# define error objects
error_x = depolarizing_error(prob_x, 1)
error_z = depolarizing_error(prob_z, 1)
error_2qubit = depolarizing_error(prob_2, 2)

noise_model = NoiseModel()
noise_model.add_all_qubit_quantum_error(error_x, ['x', 'rx'])
noise_model.add_all_qubit_quantum_error(error_z, ['rz'])
noise_model.add_all_qubit_quantum_error(error_2qubit, ['cx'])

# define simulator
simulator = Aer.get_backend('aer_simulator')

# Run and get count
results = simulator.run(transpiled_circuit,noise_model=noise_model).result()

# helper fucntion to extract results
def get_result(results):
    counts = results.get_counts()[0:len(depths) * num_samples]
    interleaved_counts = results.get_counts()[len(depths) * num_samples:]

    probabilities = []
    interleaved_probabilities = []

    for count in counts:
        probabilities.append(count[ground_state] / 1024)

    for count in interleaved_counts:
        interleaved_probabilities.append(count[ground_state] / 1024)

    new_probabilities = np.reshape(probabilities, (num_samples, len(depths)))
    new_interleaved_probabilities = np.reshape(interleaved_probabilities, (num_samples, len(depths)))

    return new_probabilities, new_interleaved_probabilities

probabilities, interleaved_probabilities = get_result(results)

# avearge the results or sdandard and intelreaved RB
mean_probabilities = np.mean(probabilities, axis=0)
mean_interleaved_probabilities = np.mean(interleaved_probabilities, axis=0)

# %% [markdown]
# # Plot

# %%
def decay_model(m, A, B, p):
    return A * p ** m + B


args = curve_fit(decay_model, depths, mean_probabilities, p0=[0.5, 0.5, 0.9])
args_interleaved = curve_fit(decay_model, depths, mean_interleaved_probabilities, p0=[0.5, 0.5, 0.9])

plt.plot(depths, mean_probabilities, '.', label='Simulated data')
plt.plot(depths, mean_interleaved_probabilities, '.', label=f'Simulated data interleaved')

plt.plot(depths, decay_model(depths, *args[0]), label=f'Fitted curve p = {args[0][2]:.3f}')
plt.plot(depths, decay_model(depths, *args_interleaved[0]),
         label=f'Fitted curve interleaved p = {args_interleaved[0][2]:.3f}')

plt.legend()
plt.title('Interleaved RB')
plt.xlabel('Depth')
plt.ylabel('Probability of measuring |0>')
d = 2
rc = (d - 1) / d * (1 - args[0][2])
rc_interleaved = (d - 1) / d * (1 - args_interleaved[0][2] / args[0][2])


plt.show()

# %% [markdown]
# average error rate per clifford (sdardard RB) : $ r_c = (d-1)/d*(1-p)$   \n
#
# CNOT error rate (inteleaved RB) : $ r_{CNOT} = (d-1)/d*(1 - p_{CNOT}/p) $

# %%
print('#### results ####')
print(f'sdandard rc = {rc:3f}')
print(f'interleaved rc = {rc_interleaved:3f} ')
print('\n')
print(f'-> depolarization parameter of interleaved gate {rc_interleaved*2:3f}')
print('should be ', prob_2)
# Out:
# #### results ####
# sdandard rc = 0.007489
# interleaved rc = 0.005276
#
#
# -> depolarization parameter of interleaved gate 0.010551
# should be  0.01

# %% [markdown]
# # Method works!
